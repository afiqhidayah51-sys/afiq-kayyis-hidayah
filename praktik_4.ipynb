# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

data = pd.DataFrame({
    'IPK': [3.5, 2.1, 3.8, 2.5, 3.2, 2.0, 3.6, 2.7, 3.9, 2.4],
    'Kehadiran': [90, 60, 95, 70, 85, 50, 92, 75, 98, 72],
    'Tinggi_Badan': [170, 160, 175, 165, 155, 180, 168, 172, 160, 167],
    'Lulus': [1, 0, 1, 0, 1, 0, 1, 1, 1, 0]
})

print(data)
# Out:
#    IPK  Kehadiran  Tinggi_Badan  Lulus
# 0  3.5         90           170      1
# 1  2.1         60           160      0
# 2  3.8         95           175      1
# 3  2.5         70           165      0
# 4  3.2         85           155      1
# 5  2.0         50           180      0
# 6  3.6         92           168      1
# 7  2.7         75           172      1
# 8  3.9         98           160      1
# 9  2.4         72           167      0

# %%
X_new = data[['IPK', 'Kehadiran']]
y = data['Lulus']

print(X_new.head())
# Out:
#    IPK  Kehadiran
# 0  3.5         90
# 1  2.1         60
# 2  3.8         95
# 3  2.5         70
# 4  3.2         85

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_new)

print(X_scaled[:5])
# Out:
# [[ 0.78135744  0.74670872]
#  [-1.28260561 -1.2357038 ]
#  [ 1.22363524  1.0771108 ]
#  [-0.69290188 -0.57489963]
#  [ 0.33907964  0.41630663]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

model = LogisticRegression()
model.fit(X_train, y_train)

prediksi = model.predict(X_test)
akurasi = accuracy_score(y_test, prediksi)

print("Akurasi Model:", akurasi)
print("Prediksi:", prediksi)
# Out:
# Akurasi Model: 1.0
# Prediksi: [1 0 0]
